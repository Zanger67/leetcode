# %%
import pandas as kungfupanda
from os import listdir
from os.path import isfile, join
import pickle

# %%
jsonFiles = [f for f in listdir() if isfile(f) and f.endswith('.json')]
print(jsonFiles)

dataFile = jsonFiles[0]
print('File to use:\t', dataFile)
# Out:
# ['leetcode question list query.json']
# File to use:	 leetcode question list query.json

# %%
questionList        = kungfupanda.read_json(dataFile)
temp                = questionList.get('data').get('problemsetQuestionList')

totalQuestionCount  = temp.get('total')
questions           = temp.get('questions')

questionDetails = {}
questionTopics  = {}

# frontendQuestionId : (title, titleSlug, paidOnly, difficulty, acRate)
for question in questions :
    questionNo  = int(question.get('frontendQuestionId'))       # int
    title       = str(question.get('title'))                    # str
    titleSlug   = str(question.get('titleSlug'))                # str
    paidOnly    = bool(question.get('paidOnly'))                # bool
    difficulty  = str(question.get('difficulty'))               # str (Easy, Medium, Hard)
    acRate      = round(float(question.get('acRate')), 3)       # float - 3 decimal places

    questionDetails[questionNo] = (title, titleSlug, paidOnly, difficulty, acRate)

    topicList = []
    for topic in question.get('topicTags') :
        topicList.append(topic.get('name'))
    
    questionTopics[questionNo] = topicList

print(f'Total questions found:\t{totalQuestionCount}')
print(questionDetails)
print(questionTopics)
# Out:
# Total questions found:	3183
# {1: ('Two Sum', 'two-sum', False, 'Easy', 52.828), 2: ('Add Two Numbers', 'add-two-numbers', False, 'Medium', 43.135), 3: ('Longest Substring Without Repeating Characters', 'longest-substring-without-repeating-characters', False, 'Medium', 34.922), 4: ('Median of Two Sorted Arrays', 'median-of-two-sorted-arrays', False, 'Hard', 40.355), 5: ('Longest Palindromic Substring', 'longest-palindromic-substring', False, 'Medium', 33.984), 6: ('Zigzag Conversion', 'zigzag-conversion', False, 'Medium', 48.301), 7: ('Reverse Integer', 'reverse-integer', False, 'Medium', 28.731), 8: ('String to Integer (atoi)', 'string-to-integer-atoi', False, 'Medium', 17.403), 9: ('Palindrome Number', 'palindrome-number', False, 'Easy', 56.652), 10: ('Regular Expression Matching', 'regular-expression-matching', False, 'Hard', 28.202), 11: ('Container With Most Water', 'container-with-most-water', False, 'Medium', 55.465), 12: ('Integer to Roman', 'integer-to-roman', False, 'Medium', 65.116), 13: ('Roman to Integer', 'roman-to-integer', False, 'Easy', 61.561), 14: ('Longest Common Prefix', 'longest-common-prefix', False, 'Easy', 43.022), 15: ('3Sum', '3sum', False, 'Medium', 34.702), 16: ('3Sum Closest', '3sum-closest', False, 'Medium', 45.857), 17: ('Letter Combinations of a Phone Number', 'letter-combinations-of-a-phone-number', False, 'Medium', 60.745), 18: ('4Sum', '4sum', False, 'Medium', 36.347), 19: ('Remove Nth Node From End of List', 'remove-nth-node-from-end-of-list', False, 'Medium', 45.658), 20: ('Valid Parentheses', 'valid-parentheses', False, 'Easy', 40.654), 21: ('Merge Two Sorted Lists', 'merge-two-sorted-lists', False, 'Easy', 64.518), 22: ('Generate Parentheses', 'generate-parentheses', False, 'Medium', 74.781), 23: ('Merge k Sorted Lists', 'merge-k-sorted-lists', False, 'Hard', 53.127), 24: ('Swap Nodes in Pairs', 'swap-nodes-in-pairs', False, 'Medium', 64.594), 25: ('Reverse Nodes in k-Group', 'reverse-nodes-in-k-group', False, 'Hard', 59.105), 26: ('Remove Duplicates from Sorted Array', 'remove-duplicates-from-sorted-array', False, 'Easy', 56.172), 27: ('Remove Element', 'remove-element', False, 'Easy', 57.135), 28: ('Find the Index of the First Occurrence in a String', 'find-the-index-of-the-first-occurrence-in-a-string', False, 'Easy', 42.599), 29: ('Divide Two Integers', 'divide-two-integers', False, 'Medium', 17.548), 30: ('Substring with Concatenation of All Words', 'substring-with-concatenation-of-all-words', False, 'Hard', 32.683), 31: ('Next Permutation', 'next-permutation', False, 'Medium', 40.204), 32: ('Longest Valid Parentheses', 'longest-valid-parentheses', False, 'Hard', 34.318), 33: ('Search in Rotated Sorted Array', 'search-in-rotated-sorted-array', False, 'Medium', 40.921), 34: ('Find First and Last Position of Element in Sorted Array', 'find-first-and-last-position-of-element-in-sorted-array', False, 'Medium', 44.505), 35: ('Search Insert Position', 'search-insert-position', False, 'Easy', 46.227), 36: ('Valid Sudoku', 'valid-sudoku', False, 'Medium', 59.889), 37: ('Sudoku Solver', 'sudoku-solver', False, 'Hard', 61.56), 38: ('Count and Say', 'count-and-say', False, 'Medium', 55.415), 39: ('Combination Sum', 'combination-sum', False, 'Medium', 71.765), 40: ('Combination Sum II', 'combination-sum-ii', False, 'Medium', 54.716), 41: ('First Missing Positive', 'first-missing-positive', False, 'Hard', 39.608), 42: ('Trapping Rain Water', 'trapping-rain-water', False, 'Hard', 62.23), 43: ('Multiply Strings', 'multiply-strings', False, 'Medium', 40.579), 44: ('Wildcard Matching', 'wildcard-matching', False, 'Hard', 28.127), 45: ('Jump Game II', 'jump-game-ii', False, 'Medium', 40.515), 46: ('Permutations', 'permutations', False, 'Medium', 78.568), 47: ('Permutations II', 'permutations-ii', False, 'Medium', 59.462), 48: ('Rotate Image', 'rotate-image', False, 'Medium', 74.716), 49: ('Group Anagrams', 'group-anagrams', False, 'Medium', 68.758), 50: ('Pow(x, n)', 'powx-n', False, 'Medium', 34.975), 51: ('N-Queens', 'n-queens' ...
# {1: ['Array', 'Hash Table'], 2: ['Linked List', 'Math', 'Recursion'], 3: ['Hash Table', 'String', 'Sliding Window'], 4: ['Array', 'Binary Search', 'Divide and Conquer'], 5: ['Two Pointers', 'String', 'Dynamic Programming'], 6: ['String'], 7: ['Math'], 8: ['String'], 9: ['Math'], 10: ['String', 'Dynamic Programming', 'Recursion'], 11: ['Array', 'Two Pointers', 'Greedy'], 12: ['Hash Table', 'Math', 'String'], 13: ['Hash Table', 'Math', 'String'], 14: ['String', 'Trie'], 15: ['Array', 'Two Pointers', 'Sorting'], 16: ['Array', 'Two Pointers', 'Sorting'], 17: ['Hash Table', 'String', 'Backtracking'], 18: ['Array', 'Two Pointers', 'Sorting'], 19: ['Linked List', 'Two Pointers'], 20: ['String', 'Stack'], 21: ['Linked List', 'Recursion'], 22: ['String', 'Dynamic Programming', 'Backtracking'], 23: ['Linked List', 'Divide and Conquer', 'Heap (Priority Queue)', 'Merge Sort'], 24: ['Linked List', 'Recursion'], 25: ['Linked List', 'Recursion'], 26: ['Array', 'Two Pointers'], 27: ['Array', 'Two Pointers'], 28: ['Two Pointers', 'String', 'String Matching'], 29: ['Math', 'Bit Manipulation'], 30: ['Hash Table', 'String', 'Sliding Window'], 31: ['Array', 'Two Pointers'], 32: ['String', 'Dynamic Programming', 'Stack'], 33: ['Array', 'Binary Search'], 34: ['Array', 'Binary Search'], 35: ['Array', 'Binary Search'], 36: ['Array', 'Hash Table', 'Matrix'], 37: ['Array', 'Hash Table', 'Backtracking', 'Matrix'], 38: ['String'], 39: ['Array', 'Backtracking'], 40: ['Array', 'Backtracking'], 41: ['Array', 'Hash Table'], 42: ['Array', 'Two Pointers', 'Dynamic Programming', 'Stack', 'Monotonic Stack'], 43: ['Math', 'String', 'Simulation'], 44: ['String', 'Dynamic Programming', 'Greedy', 'Recursion'], 45: ['Array', 'Dynamic Programming', 'Greedy'], 46: ['Array', 'Backtracking'], 47: ['Array', 'Backtracking'], 48: ['Array', 'Math', 'Matrix'], 49: ['Array', 'Hash Table', 'String', 'Sorting'], 50: ['Math', 'Recursion'], 51: ['Array', 'Backtracking'], 52: ['Backtracking'], 53: ['Array', 'Divide and Conquer', 'Dynamic Programming'], 54: ['Array', 'Matrix', 'Simulation'], 55: ['Array', 'Dynamic Programming', 'Greedy'], 56: ['Array', 'Sorting'], 57: ['Array'], 58: ['String'], 59: ['Array', 'Matrix', 'Simulation'], 60: ['Math', 'Recursion'], 61: ['Linked List', 'Two Pointers'], 62: ['Math', 'Dynamic Programming', 'Combinatorics'], 63: ['Array', 'Dynamic Programming', 'Matrix'], 64: ['Array', 'Dynamic Programming', 'Matrix'], 65: ['String'], 66: ['Array', 'Math'], 67: ['Math', 'String', 'Bit Manipulation', 'Simulation'], 68: ['Array', 'String', 'Simulation'], 69: ['Math', 'Binary Search'], 70: ['Math', 'Dynamic Programming', 'Memoization'], 71: ['String', 'Stack'], 72: ['String', 'Dynamic Programming'], 73: ['Array', 'Hash Table', 'Matrix'], 74: ['Array', 'Binary Search', 'Matrix'], 75: ['Array', 'Two Pointers', 'Sorting'], 76: ['Hash Table', 'String', 'Sliding Window'], 77: ['Backtracking'], 78: ['Array', 'Backtracking', 'Bit Manipulation'], 79: ['Array', 'String', 'Backtracking', 'Matrix'], 80: ['Array', 'Two Pointers'], 81: ['Array', 'Binary Search'], 82: ['Linked List', 'Two Pointers'], 83: ['Linked List'], 84: ['Array', 'Stack', 'Monotonic Stack'], 85: ['Array', 'Dynamic Programming', 'Stack', 'Matrix', 'Monotonic Stack'], 86: ['Linked List', 'Two Pointers'], 87: ['String', 'Dynamic Programming'], 88: ['Array', 'Two Pointers', 'Sorting'], 89: ['Math', 'Backtracking', 'Bit Manipulation'], 90: ['Array', 'Backtracking', 'Bit Manipulation'], 91: ['String', 'Dynamic Programming'], 92: ['Linked List'], 93: ['String', 'Backtracking'], 94: ['Stack', 'Tree', 'Depth-First Search', 'Binary Tree'], 95: ['Dynamic Programming', 'Backtracking', 'Tree', 'Binary Search Tree', 'Binary Tree'], 96: ['Math', 'Dynamic Programming', 'Tree', 'Binary Search Tree', 'Binary Tree'], 97: ['String', 'Dynamic Programming'], 98: ['Tree', 'Depth-First Search', 'Binary Search Tree', 'Binary Tree'], 99: ['Tree', 'Depth-First Search', 'Binary Search Tree', 'Binary Tree'], 100: ['Tree', 'Depth-Firs ...

# %%
with open('leetcode_question_details.pkl', 'wb') as fp:
    pickle.dump(questionDetails, fp)
    print('Question Details saved successfully to file')
    
with open('leetcode_question_topics.pkl', 'wb') as fp:
    pickle.dump(questionTopics, fp)
    print('Question Topics saved successfully to file')
# Out:
# Question Details saved successfully to file
# Question Topics saved successfully to file
